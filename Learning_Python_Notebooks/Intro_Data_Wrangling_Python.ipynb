# %% [markdown]
# # Data Wrangling in Pandas
# Below are some basic operations that will help you confidently begin wrangling a csv in python!

# %%
# Import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# #### Libraries not installed?
# With anaconda, you can easily install new libraries for your python notebook through your computer terminal.
# 1. Open a terminal on your computer
# 2. Type: `conda install [name of library]`
# 3. hit `enter`
# This should begin the installation process of whichever library your are trying to install. More detailed instructions can be found on the anaconda site.

# %%
#Read in csv
df = pd.read_csv('/Users/madeleineseitz/Desktop/stroop_test.csv')
#Call data frame head (this will return the first five rows of a df)
df.head()
# Out:
#     text letterColor corrAns  congruent  trials.thisRepN  trials.thisTrialN  \
# 0    red         red    left          1                0                  0
# 1   blue         red    left          0                0                  1
# 2  green       green    down          1                0                  2
# 3  green        blue   right          0                0                  3
# 4   blue        blue   right          1                0                  4
#
#    trials.thisN  trials.thisIndex  instrText.started  instrText.stopped  ...  \
# 0             0                 0          12.890473          13.897167  ...
# 1             1                 5                NaN                NaN  ...
# 2             2                 2                NaN                NaN  ...
# 3             3                 3                NaN                NaN  ...
# 4             4                 4                NaN                NaN  ...
#
# ...

# %%
#Call the data frame tail (this will return the last five rows of a df)
df.tail()
# Out:
#      text letterColor corrAns  congruent  trials.thisRepN  trials.thisTrialN  \
# 25    red         red    left          1                4                  1
# 26   blue         red    left          0                4                  2
# 27  green       green    down          1                4                  3
# 28   blue        blue   right          1                4                  4
# 29  green        blue   right          0                4                  5
#
#     trials.thisN  trials.thisIndex  instrText.started  instrText.stopped  ...  \
# 25            25                 0                NaN                NaN  ...
# 26            26                 5                NaN                NaN  ...
# 27            27                 2                NaN                NaN  ...
# 28            28                 4                NaN                NaN  ...
# 29            29                 3                NaN                NaN  ...
#
# ...

# %% [markdown]
# ### Select columns using brackets
# With square brackets, you can select one or more columns.

# %%
# Select one column using double brackets
df[['letterColor']].head()
# Out:
#   letterColor
# 0         red
# 1         red
# 2       green
# 3        blue
# 4        blue

# %%
# Select multiple columns using double brackets
df[[ 'letterColor', 'session']].head()
# Out:
#   letterColor  session
# 0         red        1
# 1         red        1
# 2       green        1
# 3        blue        1
# 4        blue        1

# %%
# This is a Pandas DataFrame
type(df[[ 'letterColor', 'session']].head())
# Out:
# pandas.core.frame.DataFrame

# %%
# Select one column using single brackets
df['session'].head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: session, dtype: int64

# %%
# This produces a pandas series which is a one-dimensional array which can be labeled
type(df['session'].head())
# Out:
# pandas.core.series.Series

# %%
# Keep in mind that you can't select multiple colums using single brackets
# This will result in a KeyError
df['letterColor', 'session']

# %% [markdown]
# #### Pandas Slicing
# With a pandas series, we can select rows using slicing like this: series[start_index:end_index]
#
# The end_index is not inclusive. This behavior is very similar to Python lists.
